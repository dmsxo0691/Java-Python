# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
# matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
x = [1,2,3]
y = [2,4,8]

plt.plot(x, y)
plt.title('꺾은선 그래프', fontdict={'family':'HYGungSo-Bold', 'size':20}) # 개별 폰트 설정
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot(x,y)
plt.xlabel('x축')
plt.ylabel('y축')
# Out:
# Text(0, 0.5, 'y축')

# %%
plt.plot(x,y)
plt.xlabel('x축', color = 'red', loc = 'right')
plt.ylabel('y축', color='#00aa00', loc = 'top')
# Out:
# Text(0, 1, 'y축')

# %%
plt.plot(x,y,label='무슨 데이터')
plt.legend()

# %%
plt.plot(x,y,label='무슨 데이터')
plt.legend(loc="upper right")

# %%
plt.plot(x,y,label='무슨 데이터')
plt.legend(loc="lower right")

# %%
plt.plot(x,y,label='범례')
plt.legend(loc=(0.1, 0.8)) # x축, y축(0~1 사이)

# %%
plt.plot(x,y, linewidth=5) #선굵기

# %%
plt.plot(x,y, marker="o")

# %%
plt.plot(x,y, marker="o", linestyle = 'none')

# %%
plt.plot(x,y, marker="o", markersize="10")

# %%
plt.plot(x,y, marker="o", markersize="20", markeredgecolor='red', markerfacecolor='yellow')

# %%
plt.plot(x,y, marker="o", linestyle=":")

# %%
plt.plot(x,y, marker="o", linestyle="--")

# %%
plt.plot(x,y, marker="o", linestyle="-.")

# %%
plt.plot(x,y, marker="o", color="b")

# %%
plt.plot(x,y, 'ro--') # color = red, marker = o, linestyle = --

# %%
plt.figure(figsize=(10,5))
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.savefig('graph.png', dpi=100)

# %%
days = [1, 2, 3] # 1일, 2일, 3일
az = [2, 4, 8] # (단위 : 만명) 1일부터 3일까지 아스트라제네카 접종인구
pfizer = [5, 1, 3] # 화이타
moderna = [1, 2, 5] # 모더나
plt.plot(days, az)
plt.plot(days, pfizer)
plt.plot(days, moderna)

# %%
plt.plot(days, az, label='az')
plt.plot(days, pfizer, label='pfizer', marker='o', linestyle='--')
plt.plot(days, moderna, label='moderna', marker='s', linestyle='-.')

plt.legend()

# %%
plt.plot(days, az, label='az')
plt.plot(days, pfizer, label='pfizer', marker='o', linestyle='--')
plt.plot(days, moderna, label='moderna', marker='s', linestyle='-.')

plt.legend(ncol=3)

# %%
lables = ['강백호', '서태웅', '정대만']
values = [190, 187, 184]
plt.bar(lables, values)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.bar(lables, values, color='r')
# Out:
# <BarContainer object of 3 artists>

# %%
labels = ['강백호', '서태웅', '정대만'] # 이름
values = [190, 187, 184] # 키
colors = ['r', 'g', 'b']
plt.bar(labels, values, color=colors, alpha=0.5)
# Out:
# <BarContainer object of 3 artists>

# %%
ticks = ['1번학생','2번학생','3번학생']
plt.bar(labels, values)
plt.xticks(labels, ticks, rotayion=80)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\KGA_09\Desktop\은태\Java-Python\20221031\graph2.ipynb 셀 27 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/KGA_09/Desktop/%EC%9D%80%ED%83%9C/Java-Python/20221031/graph2.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> ticks = ['1번학생','2번학생','3번학생']
#       <a href='vscode-notebook-cell:/c%3A/Users/KGA_09/Desktop/%EC%9D%80%ED%83%9C/Java-Python/20221031/graph2.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> plt.bar(labels, values)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/KGA_09/Desktop/%EC%9D%80%ED%83%9C/Java-Python/20221031/graph2.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> plt.xticks(labels, ticks, rotayion=80)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:1795, in xticks(ticks, labels, **kwargs)
#    1793         l.update(kwargs)
#    1794 else:
# -> 1795     labels = ax.set_xticklabels(labels, **kwargs)
#    1797 return locs, labels
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:75, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      74 def wrapper(self, *args, **kwargs):
# ---> 75     return get_method(self)(*args, **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py:1798, in Axis._set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1796 if fontdict is not None:
#    1797     kwargs.update(fontdict)
# -> 1798 return self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py:1746, in Axis.set_ticklabels(self, ticklabels, minor, **kwargs)
#    1744 # deal with label1
#    1745 tick.label1.set_text(tick_label)
# -> 1746 tick.label1.update(kwargs)
#    1747 # deal with label2
#    1748 tick.label2.set_text(tick_label)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\text.py:172, in Text.update(self, kwargs)
#     170 # Update bbox last, as it depends on font properties.
#     171 bbox = kwargs.pop("bbox", sentinel)
# --> 172 super().update(kwargs)
#     173 if bbox is not sentinel:
#     174     self.set_bbox(bbox)
#
# File c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Text' object has no property 'rotayion'

# %%
labels = ['강백호', '서태웅', '정대만'] # 이름
values = [190, 187, 184] # 키

plt.barh(labels, values)
plt.xlim(180, 195)
# Out:
# (180.0, 195.0)
