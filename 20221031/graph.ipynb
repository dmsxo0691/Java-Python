# %%
import matplotlib.pyplot as plt

x = [1,2,3]
y = [2,4,8]
plt.plot(x,y)

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x,y)
plt.title('꺾은선 그래프')
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans Mono',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'cmmi10',
#  'STIXSizeFiveSym',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'cmr10',
#  'STIXGeneral',
#  'DejaVu Serif Display',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'DejaVu Sans Display',
#  'STIXSizeThreeSym',
#  'cmb10',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'cmsy10',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXSizeOneSym',
#  'cmtt10',
#  'STIXGeneral',
#  'cmss10',
#  'DejaVu Serif',
#  'STIXSizeTwoSym',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'STIXNonUnicode',
#  'cmex10',
#  'NanumSquareOTF',
#  'Lucida Sans Typewriter',
#  'Century Gothic',
#  'Goudy Old Style',
#  'Candara',
#  'Microsoft Tai Le',
#  'NanumSquareOTF',
#  'Century Gothic',
#  'Leelawadee UI',
#  'Bodoni MT',
#  'Matura MT Script Capitals',
#  'Arial',
#  'Lucida Sans',
#  'Wingdings',
#  'Courier New',
#  'Vivaldi',
#  'Segoe Script',
#  'Arial',
#  'Gigi',
#  'Impact',
#  'Chiller',
#  'Franklin Gothic Heavy',
#  'Bodoni MT',
#  'Yet R',
#  'Candara',
#  'Snap ITC',
#  'Bell MT',
#  'MS Gothic',
#  'Calibri',
#  'Calisto MT',
#  'Tw Cen MT Condensed',
#  'HYGraphic-Medium',
#  'Times New Roman',
#  'Segoe UI Emoji',
#  'Tempus Sans ITC',
#  'Candara',
#  'Gill Sans MT',
#  'Broadway',
#  'HYGothic-Medium',
#  'Gloucester MT Extra Condensed',
#  'NanumSquare_ac',
#  'Microsoft Tai Le',
#  'Corbel',
#  'Consolas',
#  'Arial',
#  'Cambria',
#  'Corbel',
#  'Modern No. 20',
#  'Parchment',
#  'Cascadia Code',
#  'Trebuchet MS',
#  'Franklin Gothic Medium Cond',
#  'Berlin Sans FB',
#  'Sitka Small',
#  'Tw Cen MT',
#  'Arial',
#  'Courier New',
#  'Malgun Gothic',
#  'Leelawadee UI',
#  'HYPMokGak-Bold',
#  'Lucida Console',
#  'Century Schoolbook',
#  'Eras Light ITC',
#  'Book Antiqua',
#  'NanumSquareOTF_ac',
#  'Trebuchet MS',
#  'Forte',
#  'Perpetua',
#  'Segoe UI',
#  'Myanmar Text',
#  'Century Schoolbook',
#  'Gill Sans Ultra Bold Condensed',
#  'Agency FB',
#  'Goudy Old Style',
#  'HCR Dotum',
#  'Segoe Script',
#  'Stencil',
#  'Footlight MT Light',
#  'Arial',
#  'Century Schoolbook',
#  'Lucida Fax',
#  'Trebuchet MS',
#  'Maiandra GD',
#  'Rockwell Condensed',
#  'Rockwell Condensed',
#  'Segoe UI',
#  'Playbill',
#  'Bell MT',
#  'Corbel',
#  'Gmarket Sans TTF',
#  'Bernard MT Condensed',
#  'MV Boli',
#  'Perpetua',
#  'Perpetua',
#  'Tw Cen MT',
#  'Lucida Sans Typewriter',
#  'Segoe Print',
#  'Calisto MT',
#  'Gulim',
#  'Lucida Sans Typewriter',
#  'Century Gothic',
#  'Engravers MT',
#  'Segoe UI',
#  'Javanese Text',
#  'Lucida Sans',
#  'Gulim',
#  'Showcard Gothic',
#  'Cambria',
#  'High Tower Text',
#  'Copperplate Gothic Light',
#  'Century Schoolbook',
#  'Showcard Gothic',
#  'Chiller',
#  'Harrington',
#  'HoloLens MDL2 Assets',
#  'Californian FB',
#  'Cascadia Code',
#  'Candara',
#  'HYGungSo-Bold',
#  'HYGothic-Extra',
#  'Georgia',
#  'Copperplate Gothic Bold',
#  'Microsoft JhengHei',
#  'Bookman Old Style',
#  'Microsoft Yi Baiti',
#  'Eras Light ITC',
#  'Britannic Bold',
#  'Headline R',
#  'Tw Cen MT',
#  'HYGothic-Extra',
#  'Segoe UI',
#  'Cooper Black',
#  'Microsoft YaHei',
#  'Franklin Gothic Demi',
#  'Wide Latin',
#  'Palatino Linotype',
#  'Baskerville Old Face',
#  'Calibri',
#  'Microsoft Sans Serif',
#  'Century Schoolbook',
#  'Perpetua',
#  'Lucida Sans',
#  'Franklin Gothic Book',
#  'Segoe UI',
#  'Malgun Gothic',
#  'Bradley Hand ITC',
#  'Candara',
#  'Calibri',
#  'Calibri',
#  'Book Antiqua',
#  'Franklin Gothic Demi',
#  'Century Schoolbook',
#  'Curlz MT',
#  'Calibri',
#  'Magic R',
#  'netmarble',
#  'Lucida Bright',
#  'Segoe Script',
#  'Century Schoolbook',
#  'Times New Roman',
#  'Yu Gothic',
#  'HYSinMyeongJo-Medium',
#  'Palatino Linotype',
#  'Calibri',
#  'Eras Medium ITC',
#  'Franklin Gothic Heavy',
#  'MS Outlook',
#  'Calisto MT',
#  'Verdana',
#  'Courier New',
#  'Perpetua',
#  'Calisto MT',
#  'HYSinMyeongJo-Medium',
#  'Bookman Old Style',
#  'Colonna MT',
#  'Californian FB',
#  'HoloLens MDL2 Assets',
#  'Rockwell',
#  'Times New Roman',
#  'Perpetua Titling MT',
#  'Microsoft PhagsPa',
#  'Segoe UI',
#  'Times New Roman',
#  'NanumSquareOTF_ac',
#  'Wide Latin',
#  'HCR Batang',
#  'Franklin Gothic Medium',
#  'Candara',
#  'Garamond',
#  'Agency FB',
#  'Microsoft JhengHei',
#  'Bodoni MT',
#  'Gill Sans MT Condensed',
#  'Lucida Sans Typewriter',
#  'HYPost-Medium',
#  'Gmarket Sans TTF',
#  'Franklin Gothic Medium',
#  'Gill Sans MT',
#  'MS Reference Specialty',
#  'Tahoma',
#  'Segoe UI',
#  'NanumSquare_ac',
#  'Rage Italic',
#  'Tahoma',
#  'Viner Hand ITC',
#  'Pristina',
#  'NanumSquareOTF_ac',
#  'Segoe UI',
#  'Verdana',
#  'Consolas',
#  'Goudy Stout',
#  'Blackadder ITC',
#  'Segoe UI',
#  'Pristina',
#  'Batang',
#  'Haettenschweiler',
#  'Papyrus',
#  'Gabriola',
#  'Candara',
#  'Bauhaus 93',
#  'Juice ITC',
#  'Lucida Sans',
#  'Microsoft New Tai Lue',
#  'Lucida Calligraphy',
#  'Wingdings 2',
#  'NanumSquare',
#  'Goudy Old Style',
#  'Lucida Fax',
#  'Eras Medium ITC',
#  'HCR Dotum',
#  'Tahoma',
#  'Corbel',
#  'Bodoni MT',
#  'Sitka Small',
#  'Malgun Gothic',
#  'Bodoni MT',
#  'Segoe UI Emoji',
#  'Franklin Gothic Book',
#  'Franklin Gothic Heavy',
#  'Corbel',
#  'Georgia',
#  'Edwardian Script ITC',
#  'Segoe UI Historic',
#  'Tw Cen MT',
#  'Segoe UI',
#  'Gill Sans MT',
#  'Javanese Text',
#  'Microsoft New Tai Lue',
#  'Perpetua Titling MT',
#  'Lucida Sans Typewriter',
#  'Ebrima',
#  'Bodoni MT',
#  'Bahnschrift',
#  'Imprint MT Shadow',
#  'Engravers MT',
#  'Sitka Small',
#  'Franklin Gothic Demi',
#  'Yet R',
#  'Arial',
#  'Tw Cen MT Condensed Extra Bold',
#  'Tw Cen MT Condensed',
#  'Trebuchet MS',
#  'French Script MT',
#  'Lucida Fax',
#  'Corbel',
#  'Microsoft YaHei',
#  'Microsoft JhengHei',
#  'Arial',
#  'HYPMokGak-Bold',
#  'Candara',
#  'Bernard MT Condensed',
#  'Trebuchet MS',
#  'Old English Text MT',
#  'Franklin Gothic Demi',
#  'Franklin Gothic Medium Cond',
#  'Rage Italic',
#  'Sitka Small',
#  'Courier New',
#  'Century Gothic',
#  'Lucida Bright',
#  'Gabriola',
#  'Book Antiqua',
#  'Cambria',
#  'Bodoni MT',
#  'Bodoni MT',
#  'Gill Sans MT',
#  'Perpetua',
#  'HYPost-Light',
#  'Lucida Calligraphy',
#  'HYGungSo-Bold',
#  'Mistral',
#  'Gill Sans MT',
#  'Castellar',
#  'Lucida Bright',
#  'Malgun Gothic',
#  'Constantia',
#  'Arial',
#  'Bodoni MT',
#  'Century Gothic',
#  'Yu Gothic',
#  'Nirmala UI',
#  'High Tower Text',
#  'Bahnschrift',
#  'Comic Sans MS',
#  'Berlin Sans FB',
#  'Trebuchet MS',
#  'Segoe UI',
#  'Book Antiqua',
#  'Centaur',
#  'Microsoft PhagsPa',
#  'Gigi',
#  'Lucida Fax',
#  'Lucida Sans Unicode',
#  'Ebrima',
#  'Tw Cen MT Condensed',
#  'Harrington',
#  'Segoe UI',
#  'Calisto MT',
#  'Gmarket Sans TTF',
#  'Bodoni MT',
#  'Bookshelf Symbol 7',
#  'Cascadia Mono',
#  'Segoe UI',
#  'Comic Sans MS',
#  'Goudy Stout',
#  'MoeumT R',
#  'NanumSquareOTF',
#  'Century Gothic',
#  'Baskerville Old Face',
#  'Gadugi',
#  'Niagara Engraved',
#  'Microsoft YaHei',
#  'Consolas',
#  'Vivaldi',
#  'Microsoft PhagsPa',
#  'Calibri',
#  'MS Reference Sans Serif',
#  'Gadugi',
#  'Tw Cen MT',
#  'MS Reference Sans Serif',
#  'Freestyle Script',
#  'NanumGothicOTF',
#  'Georgia',
#  'Cambria',
#  'Britannic Bold',
#  'Cambria',
#  'Haettenschweiler',
#  'Algerian',
#  'Berlin Sans FB Demi',
#  'Bodoni MT',
#  'Microsoft JhengHei',
#  'Bookman Old Style',
#  'SimSun',
#  'Lucida Sans',
#  'Gadugi',
#  'Gill Sans MT Ext Condensed Bold',
#  'Gill Sans Ultra Bold Condensed',
#  'Bodoni MT',
#  'Arial Rounded MT Bold',
#  'Bodoni MT',
#  'Verdana',
#  'Elephant',
#  'Freestyle Script',
#  'NanumGothicOTF',
#  'Georgia',
#  'Ink Free',
#  'MoeumT R',
#  'Franklin Gothic Heavy',
#  'Californian FB',
#  'Ink Free',
#  'Palace Script MT',
#  'Garamond',
#  'Calibri',
#  'Niagara Solid',
#  'Imprint MT Shadow',
#  'Book Antiqua',
#  'Yu Gothic',
#  'Palatino Linotype',
#  'Script MT Bold',
#  'Verdana',
#  'Comic Sans MS',
#  'netmarble',
#  'OCR A Extended',
#  'Tw Cen MT',
#  'Bodoni MT',
#  'Candara',
#  'Californian FB',
#  'Consolas',
#  'Elephant',
#  'Mistral',
#  'Marlett',
#  'Goudy Old Style',
#  'Rockwell Extra Bold',
#  'Cambria',
#  'Arial',
#  'Courier New',
#  'Sitka Small',
#  'Wingdings 3',
#  'Times New Roman',
#  'Sylfaen',
#  'Rockwell',
#  'Ami R',
#  'Lucida Bright',
#  'Edwardian Script ITC',
#  'Rockwell Condensed',
#  'Lucida Handwriting',
#  'Brush Script MT',
#  'Magneto',
#  'Bodoni MT',
#  'Footlight MT Light',
#  'Segoe UI',
#  'Ravie',
#  'Garamond',
#  'Lucida Bright',
#  'Corbel',
#  'Century Gothic',
#  'Symbol',
#  'Book Antiqua',
#  'Jokerman',
#  'Monotype Corsiva',
#  'Bell MT',
#  'Constantia',
#  'Century Gothic',
#  'Colonna MT',
#  'Comic Sans MS',
#  'Ami R',
#  'HCR Batang',
#  'Niagara Engraved',
#  'Palatino Linotype',
#  'Kunstler Script',
#  'Vladimir Script',
#  'Segoe MDL2 Assets',
#  'Arial',
#  'High Tower Text',
#  'Segoe UI',
#  'Perpetua',
#  'Pyunji R',
#  'Batang',
#  'HYMyeongJo-Extra',
#  'Gill Sans MT',
#  'Lucida Sans',
#  'Georgia',
#  'Lucida Sans Typewriter',
#  'Rockwell Extra Bold',
#  'Corbel',
#  'Perpetua',
#  'Lucida Sans',
#  'Palace Script MT',
#  'Book Antiqua',
#  'Malgun Gothic',
#  'MV Boli',
#  'Nirmala UI',
#  'Bookman Old Style',
#  'MS Reference Specialty',
#  'Script MT Bold',
#  'Modern No. 20',
#  'Onyx',
#  'Lucida Sans Typewriter',
#  'Times New Roman',
#  'Segoe MDL2 Assets',
#  'Tahoma',
#  'Leelawadee UI',
#  'Microsoft Himalaya',
#  'Wingdings 2',
#  'Gadugi',
#  'Parchment',
#  'Lucida Bright',
#  'Copperplate Gothic Light',
#  'Segoe Print',
#  'Sitka Small',
#  'Bookshelf Symbol 7',
#  'Trebuchet MS',
#  'Myanmar Text',
#  'Franklin Gothic Demi Cond',
#  'Tw Cen MT',
#  'Californian FB',
#  'Rockwell',
#  'Candara',
#  'Bookman Old Style',
#  'Constantia',
#  'Franklin Gothic Medium',
#  'Matura MT Script Capitals',
#  'Papyrus',
#  'Berlin Sans FB Demi',
#  'Gill Sans MT',
#  'SimSun',
#  'Rockwell',
#  'Arial',
#  'Goudy Old Style',
#  'Bauhaus 93',
#  'Yu Gothic',
#  'Lucida Fax',
#  'Algerian',
#  'Palatino Linotype',
#  'NewJumja',
#  'Verdana',
#  'Impact',
#  'Agency FB',
#  'Comic Sans MS',
#  'Segoe UI',
#  'Verdana',
#  'Nirmala UI',
#  'Jokerman',
#  'Microsoft PhagsPa',
#  'Lucida Console',
#  'Poor Richard',
#  'Lucida Sans',
#  'Nirmala UI',
#  'Bodoni MT',
#  'HYMyeongJo-Extra',
#  'Blackadder ITC',
#  'Cooper Black',
#  'Rockwell',
#  'Eras Bold ITC',
#  'Elephant',
#  'Palatino Linotype',
#  'Microsoft New Tai Lue',
#  'Constantia',
#  'Segoe UI',
#  'Bookman Old Style',
#  'Microsoft Tai Le',
#  'Courier New',
#  'Californian FB',
#  'New Gulim',
#  'Times New Roman',
#  'Franklin Gothic Book',
#  'Cascadia Mono',
#  'Vladimir Script',
#  'HYShortSamul-Medium',
#  'NanumSquare_ac',
#  'Brush Script MT',
#  'Curlz MT',
#  'Microsoft Himalaya',
#  'Myanmar Text',
#  'HYHeadLine-Medium',
#  'Old English Text MT',
#  'Lucida Fax',
#  'Tempus Sans ITC',
#  'Segoe UI Historic',
#  'Sitka Small',
#  'Microsoft JhengHei',
#  'NanumGothicOTF',
#  'Courier New',
#  'Kristen ITC',
#  'Symbol',
#  'Leelawadee UI',
#  'Lucida Bright',
#  'Microsoft Tai Le',
#  'Franklin Gothic Medium',
#  'Bell MT',
#  'Corbel',
#  'Rockwell Condensed',
#  'Bodoni MT',
#  'Centaur',
#  'Nirmala UI',
#  'Georgia',
#  'Felix Titling',
#  'Lucida Fax',
#  'Segoe Print',
#  'MingLiU-ExtB',
#  'HYPost-Medium',
#  'Microsoft Yi Baiti',
#  'MS Outlook',
#  'Comic Sans MS',
#  'Calibri',
#  'Microsoft JhengHei',
#  'Goudy Old Style',
#  'Garamond',
#  'Rockwell',
#  'Eras Demi ITC',
#  'MT Extra',
#  'Pyunji R',
#  'Calibri',
#  'Webdings',
#  'Rockwell',
#  'Arial',
#  'HyhwpEQ',
#  'Bodoni MT',
#  'HYShortSamul-Medium',
#  'NanumSquare_ac',
#  'High Tower Text',
#  'Arial',
#  'Microsoft Sans Serif',
#  'Bookman Old Style',
#  'Bodoni MT',
#  'Playbill',
#  'Segoe UI',
#  'Corbel',
#  'Comic Sans MS',
#  'HYPost-Light',
#  'Microsoft New Tai Lue',
#  'Harlow Solid Italic',
#  'Lucida Fax',
#  'Yu Gothic',
#  'Cambria',
#  'Kristen ITC',
#  'Bell MT',
#  'Garamond',
#  'Onyx',
#  'NanumSquare',
#  'Gill Sans Ultra Bold',
#  'Courier New',
#  'Century',
#  'Segoe UI',
#  'Arial Rounded MT Bold',
#  'Eras Bold ITC',
#  'MS Gothic',
#  'Segoe UI Symbol',
#  'Candara',
#  'OCR A Extended',
#  'NanumSquareOTF_ac',
#  'Bodoni MT',
#  'Eras Demi ITC',
#  'Cambria',
#  'Informal Roman',
#  'Constantia',
#  'Headline R',
#  'Segoe UI Symbol',
#  'Constantia',
#  'Magneto',
#  'Wingdings',
#  'Tw Cen MT Condensed Extra Bold',
#  'Book Antiqua',
#  'Times New Roman',
#  'Consolas',
#  'Ebrima',
#  'HYGraphic-Medium',
#  'Segoe UI',
#  'Bradley Hand ITC',
#  'Forte',
#  'Microsoft YaHei',
#  'Gloucester MT Extra Condensed',
#  'Segoe Script',
#  'Constantia',
#  'Leelawadee UI',
#  'Candara',
#  'Franklin Gothic Book',
#  'Castellar',
#  'Bodoni MT',
#  'Calisto MT',
#  'Sitka Small',
#  'Microsoft YaHei',
#  'NanumSquareOTF',
#  'Arial',
#  'Bell MT',
#  'Ravie',
#  'Calisto MT',
#  'HyhwpEQ',
#  'Felix Titling',
#  'Kunstler Script',
#  'Segoe UI',
#  'Ebrima',
#  'NanumSquare',
#  'Gill Sans Ultra Bold',
#  'Georgia',
#  'Tw Cen MT Condensed',
#  'Viner Hand ITC',
#  'Mongolian Baiti',
#  'Palatino Linotype',
#  'Arial',
#  'Perpetua Titling MT',
#  'Bodoni MT',
#  'Arial',
#  'Copperplate Gothic Bold',
#  'Lucida Sans Typewriter',
#  'Corbel',
#  'NanumSquare',
#  'Gill Sans MT Condensed',
#  'Segoe Print',
#  'Malgun Gothic',
#  'Mongolian Baiti',
#  'Informal Roman',
#  'Snap ITC',
#  'Comic Sans MS',
#  'Arial',
#  'Gill Sans MT',
#  'Maiandra GD',
#  'Consolas',
#  'Consolas',
#  'Verdana',
#  'Franklin Gothic Demi Cond',
#  'Niagara Solid',
#  'HYHeadLine-Medium',
#  'Berlin Sans FB',
#  'Poor Richard',
#  'NewJumja',
#  'Consolas',
#  'Elephant',
#  'Calisto MT',
#  'Lucida Handwriting',
#  'Leelawadee UI',
#  'Century',
#  'Lucida Sans Unicode',
#  'Broadway',
#  'Rockwell',
#  'Tw Cen MT',
#  'Stencil',
#  'Berlin Sans FB',
#  'Segoe UI',
#  'Yu Gothic',
#  'Segoe UI',
#  'Magic R',
#  'SimSun-ExtB',
#  'Calibri',
#  'Bookman Old Style',
#  'Nirmala UI',
#  'Lucida Bright',
#  'Garamond',
#  'Sylfaen',
#  'Palatino Linotype',
#  'netmarble',
#  'Calibri',
#  'Verdana',
#  'New Gulim',
#  'Georgia',
#  'Perpetua Titling MT',
#  'Agency FB',
#  'MingLiU-ExtB',
#  'Corbel',
#  'Harlow Solid Italic',
#  'Century Schoolbook',
#  'Segoe UI',
#  'Arial',
#  'Constantia',
#  'Yu Gothic',
#  'Wingdings 3',
#  'Webdings',
#  'French Script MT',
#  'HYGothic-Medium',
#  'SimSun-ExtB',
#  'Trebuchet MS',
#  'Monotype Corsiva',
#  'Juice ITC',
#  'Myanmar Text',
#  'Gill Sans MT Ext Condensed Bold',
#  'NanumGothicOTF',
#  'Microsoft YaHei',
#  'Yu Gothic']
