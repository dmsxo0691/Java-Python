# %%
#웹 스크랩핑 : 웹 사이트로부터 데이터 추출
#웹 크롤러 : 웹 인덱싱을 위해 www를 체계적으로 탐색하는 것
#파싱 : 일련의 문자열 분석

# %%
#웹 파싱
pip list
# Out:
#   Input In [2]
#     pip list
#         ^
# SyntaxError: invalid syntax

# %%
pip install beautifulsoup4 #웹 페이지 정보를 쉽게 스크랩할 수 있도록 보조
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests #http 요청을 보낼 수 있도록 보조
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#파싱할 페이지 분석
# 1. 가비아 라이브러리 홈페이지 library.gabia.com
# 소스 보기, html 소스를 살펴보면 게시글의 제목, 링크, 날짜
import requests
from bs4 import BeautifulSoup as bs

page = requests.get("http://library.gabia.com")

soup = bs(page.text, "html.parser")

elements = soup.select('div.esg-entry-content a.eg-grant-element-0')
for index, element in enumerate(elements, 1):
    print("{}번째 게시글의 제목 : {}, {}".format(index, element.text, element.attrs['href']))
# Out:
# 1번째 게시글의 제목 : 협업툴, 모두의 스케줄을 파악하는 진짜 협업 방법, https://library.gabia.com/contents/groupware/11814/
# 2번째 게시글의 제목 : 돌아온 사무실, 그룹웨어로 회의실 잡기, https://library.gabia.com/contents/groupware/11792/
# 3번째 게시글의 제목 : 전자결재, 문서철 작업에서 벗어나는 방법, https://library.gabia.com/contents/groupware/11774/
# 4번째 게시글의 제목 : 핵심산업 클라우드 플래그십 프로젝트 핵심정리, https://library.gabia.com/contents/infrahosting/11729/
# 5번째 게시글의 제목 : 전자결재, 페이퍼리스 2.0 시대로 향하는 방법, https://library.gabia.com/contents/groupware/11713/
# 6번째 게시글의 제목 : 기업메신저, 채팅과 쪽지도 기업의 자산?!, https://library.gabia.com/contents/groupware/11696/
# 7번째 게시글의 제목 : 기업메신저, 업무 스타일에 딱 맞게 설정, https://library.gabia.com/contents/groupware/11687/
# 8번째 게시글의 제목 : 기업메신저로 조직의 업무 스트레스 줄이는 방법, https://library.gabia.com/contents/groupware/11645/
# 9번째 게시글의 제목 : 클라우드 도입 시 MSP 선정 기준 3가지, https://library.gabia.com/contents/infrahosting/11598/
# 10번째 게시글의 제목 : 클라우드, 손해 안 보고 제대로 쓰려면? ③ - 클라우드 구성 방식, https://library.gabia.com/contents/infrahosting/11540/
# ...

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

page = requests.get("http://library.gabia.com")

soup = bs(page.text, "html.parser")

elements = soup.select('div.esg-entry-content a.eg-grant-element-0')

titles = []
links = []

for index, element in enumerate(elements, 1):
    titles.append(element.text)
    links.append(element.attrs['href'])

df = pd.DataFrame()
df['titles'] = titles
df['links'] = links

df.to_excel('./library_gabia.xlsx', sheet_name='Sheet1')
