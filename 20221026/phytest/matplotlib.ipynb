# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[2,3,4,5]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=[1,2,3,4]
y=[2,3,4,5]
plt.bar(x,y)
plt.show()
plt.savefig('test')

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes1 = figure.add_subplot(121)
axes2 = figure.add_subplot(122)

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot()
x=[1,2,3,4]
y=[2,4,6,8]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes1 = figure.add_subplot(211)
axes2 = figure.add_subplot(212)

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes1 = figure.add_subplot(221)
axes2 = figure.add_subplot(222)
axes3 = figure.add_subplot(223)
axes4 = figure.add_subplot(224)

# %%
import matplotlib.pyplot as plt
import numpy as np

figure = plt.figure()
axes = figure.add_subplot(111)
x=[1,2,3,4]
y=[2,4,6,8]

x2=np.array([1,2,3,4])
y2=np.array([4,1,3,6])
axes.plot(x,y,color="red",linestyle='dashed',marker='^')
axes.plot(x2,y2,color="k",linestyle='dotted',marker='o')
plt.show()

# %%
import matplotlib.pyplot as plt
#x,y축을 기준으로 2개의 다른 축을 가질 경우 
#twinx : x축을 기준으로 두개의 bar와 plot 형태의 y축 그래프 생성

figure = plt.figure()
axes = figure.add_subplot(111)
axes2 = axes.twinx()
x=[1,2,3,4]
y=[2,4,6,8]

x2=[1,2,3,4]
y2=[4,6,1,9]
axes.bar(x,y,color="green", label="bar")
axes2.plot(x2,y2,color="b", label="plot")
axes.legend()
axes2.legend(loc=1)

plt.show()
#데이터 값이 중복되는 경우 겹쳐져 안 보이는 경우를 주의해야 함

# %%
import matplotlib.pyplot as plt
# 점그래프(산점도 그래프) 생성
# 데이터의 분포를 파악하기 쉬움

figure = plt.figure()
axes = figure.add_subplot(111)
x=[1,2,3,4]
y=[2,4,6,8]
x2=[1,2,3,4]
y2=[4,6,1,9]
axes.scatter(x,y)
axes.scatter(x2,y2)
plt.show()

# %%
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(111)

label = ['하나','둘','셋','넨']
data = [1,1,2,3]

axes.pie(data, labels=label)
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
font_path = "C:/Users/KGA_09/AppData/Local/Microsoft/Windows/Fonts/NanumGothic.otf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)
import matplotlib.pyplot as plt

figure = plt.figure()
axes = figure.add_subplot(111)

label = ['하나','둘','셋','넷']
data = [1,1,2,3]

axes.pie(data, labels=label)
plt.savefig('test.jpg')

# %%
import wordcloud
text = "python python hello data"
wc = wordcloud.WordCloud() #wordcloud 객체 생성
wc.generate_from_text(text)#generate_from_text 함수 활용
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x28392136580>

# %%
pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import wordcloud
text = {"python":10, 'hello':1, 'data':4}
wc = wordcloud.WordCloud() #wordcloud 객체 생성
wc.generate_from_frequencies(text)#generate_from_frequencies 함수 활용
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x28394510D00>

# %%
import wordcloud
text = "파이썬 파이썬 시각화 데이터 분석"
wc = wordcloud.WordCloud(font_path = "C:/Users/KGA_09/AppData/Local/Microsoft/Windows/Fonts/NanumGothic.otf", background_color="pink")
wc.generate_from_text(text)
wc.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x283944A2C40>

# %%
import wordcloud
text = "파이썬 파이썬 시각화 데이터 분석"
wc = wordcloud.WordCloud(font_path = "C:/Users/KGA_09/AppData/Local/Microsoft/Windows/Fonts/NanumGothic.otf", background_color="pink")
wc.generate_from_text(text)
wc.to_file('text2.jpg')

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']
explode = [0.05, 0.05, 0.05, 0.05]

plt.pie(ratio, labels=labels, autopct='%.1f%%', startangle=260, counterclock=False, explode=explode, shadow=True)
plt.show()

# %%
import matplotlib.pyplot as plt

ratio = [34, 32, 16, 18]
labels = ['Apple', 'Banana', 'Melon', 'Grapes']

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()
